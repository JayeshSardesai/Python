# %%
import pandas as pd
import numpy as np
import matplot.pyplot as plt
import seaborn as sns

# %%
df=pd.DataFrame({"Size":["s","m","l","xl","s","m","l","s","l","s","s","l","xl","m"]})
df.head()
# Out:
#   Size
# 0    s
# 1    m
# 2    l
# 3   xl
# 4    s

# %%
ord_data=[["s","m","l","xl"]]

# %%
from sklearn.preprocessing import OrdinalEncoder

# %%
oe=OrdinalEncoder(categories=ord_data)
oe.fit(df[["Size"]])
# Out:
# OrdinalEncoder(categories=[['s', 'm', 'l', 'xl']])

# %%
df["Size_en"]=oe.transform(df[["Size"]])

# %%
df
# Out:
#    Size  Size_en
# 0     s      0.0
# 1     m      1.0
# 2     l      2.0
# 3    xl      3.0
# 4     s      0.0
# 5     m      1.0
# 6     l      2.0
# 7     s      0.0
# 8     l      2.0
# 9     s      0.0
# 10    s      0.0
# 11    l      2.0
# 12   xl      3.0
# 13    m      1.0

# %%
ord_data1={"s":5,"m":6,"l":7,"xl":8}

# %%
df["Size_en_map"]=df["Size"].map(ord_data1)

# %%
df
# Out:
#    Size  Size_en  Size_en_map
# 0     s      0.0            5
# 1     m      1.0            6
# 2     l      2.0            7
# 3    xl      3.0            8
# 4     s      0.0            5
# 5     m      1.0            6
# 6     l      2.0            7
# 7     s      0.0            5
# 8     l      2.0            7
# 9     s      0.0            5
# 10    s      0.0            5
# 11    l      2.0            7
# 12   xl      3.0            8
# 13    m      1.0            6

# %%
dataset=pd.read_csv("loanTrain.csv")

# %%
dataset.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# ...

# %%
dataset["Property_Area"].unique()
# Out:
# array(['Urban', 'Rural', 'Semiurban'], dtype=object)

# %%
dataset["Property_Area"].fillna(dataset["Property_Area"].mode()[0],inplace=True)

# %%
dataset["Property_Area"].isnull().sum()
# Out:
# 0

# %%
data=[['Urban','Rural','Semiurban']]

# %%
model=OrdinalEncoder(categories=data)

# %%
dataset["Property_Area"] =model.fit_transform(dataset[["Property_Area"]])

# %%
dataset.head(10)
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
# 5  LP001011   Male     Yes          2      Graduate           Yes
# 6  LP001013   Male     Yes          0  Not Graduate            No
# 7  LP001014   Male     Yes         3+      Graduate            No
# 8  LP001018   Male     Yes          2      Graduate            No
# 9  LP001020   Male     Yes          1      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# ...

# %%
import numpy as np
import matplot.pyplot as plt
import seaborn as sns
